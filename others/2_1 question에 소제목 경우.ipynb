# %%
#csv df로 불러오기
import pandas as pd
df=pd.read_csv('jobkorea.csv')

# %%
df.loc[21200:21210]
# Out:
#         section    company       date work_type        job  \
# 21200  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21201  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21202  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21203  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21204  엔지니어링·설계     한국전력공사  2019년 상반기        신입  전기·전자엔지니어
# 21205  엔지니어링·설계     한국전력공사  2019년 상반기        신입  전기·전자엔지니어
# 21206  엔지니어링·설계     한국전력공사  2019년 상반기        신입  전기·전자엔지니어
# 21207  엔지니어링·설계      전력거래소  2019년 상반기        신입  전기·전자엔지니어
# 21208  엔지니어링·설계      전력거래소  2019년 상반기        신입  전기·전자엔지니어
# 21209  엔지니어링·설계      전력거래소  2019년 상반기        신입  전기·전자엔지니어
# 21210  엔지니어링·설계  ㈜포스코인터내셔널  2019년 상반기        신입     화학엔지니어
#
#                                                 question  \
# 21200     지금까지 살아오면서 스스로 생각하기에 가장 큰 성공사례와 실패사례를 소개해 주세요.
# 21201    팀 단위의 과제 혹은 프로젝트 활동 경험을 한 가지 선택하여 자세하게 소개해 주세요.
# 21202                         창의성을 발휘한 경험을 자세하게 소개해 주세요.
# 21203   우리 회사를 지원한 동기와 희망직무에 대하여 준비해 온 것을 기술하여 주시기 바랍니다.
# 21204               [통섭형 인재 - 융·복합적인 사고를 바탕으로 전문성을 키우다.]
# 21205                [한국전력공사와 함께 국가 전력산업발전에 이바지하고 싶습니다.]
# 21206                       [마이크로그리드의 발전. KEPCO Open MG]
# 21207  개인적인 손해를 감수하면서 맡은 일에 대해 최선을 다했던 경험에 대해 서술해주십시오...
# 21208  공동의 목표를 달성하기 위해 의견/관점 등이 서로 다른 다양한 구성원과 협력하여 시...
# 21209  지금까지 살아오면서 도전해 본 가장 어려운 일에 대해 서술해주십시오. (해당 경험의...
# 21210                   본인을 대표할 수 있는 이력 세가지를 기술하여 주십시오.
#
#                                                   answer
# 21200  1.성공사례 복학 후 2학년 때 '실맥문학회' 동아리의 회장을 맡아 졸업하신 동아리...
# 21201  작년 9월 교내 캡스톤 디자인 공모전을 나간 경험이 있습니다. 공모전 준비를 위해 ...
# 21202  사업계획서를 제작해 지원금을 얻어냈습니다.  대학교 3학년, 학생회 기획부로 있었을...
# 21203  우리나라의 제지산업의 선두주자이며 해외의 기업들까지 인수하며 성장하는 한솔제지에서 ...
# 21204  "통섭형 인재 - 융·복합적인 사고를 바탕으로 전문성을 키우다" 4차산업 혁명이 도...
# 21205  "한국전력공사와 함께 국가 전력산업발전에 이바지하고 싶습니다" 기업을 선택하는 과정...
# 21206  "마이크로그리드의 발전. KEPCO Open MG" 한국전력공사는 마이크로그리드에 ...
# 21207  "밤을 새우며 주어진 업무를 수행했던 경험" 책임감을 느끼고 맡은 업무를 수행하여 ...
# 21208  "직원 모두의 요구를 충족시킨 워크숍 계획. 결과는 대성공!" 단기 현장실습을 하면...
# 21209  "첫 사회생활을 공사현장에서 시작하다!" 4학년 마지막 학기에 건설현장에서 전기현장...
# 21210  "자원개발을 위한 준비들" 화학지식, 꼼꼼함, 외국어 회화 능력을 갖추고 있습니다....

# %%
# 코드 순서 변경 하면 안됩니다! 
df.drop(df.index[28636: 28638],inplace=True) #28636~28638
df.drop(df.index[27273],inplace= True)
df.drop(df.index[26109 :26114],inplace=True) #26109 ~26113
df.drop(df.index[25158 : 25160],inplace=True) #25158 ~25159
df.drop(df.index[25011:25015],inplace=True) #25011 ~25014
df.drop(df.index[22693:22696],inplace=True) #22693 ~22695
df.drop(df.index[21204:21207],inplace=True) #21204 ~21206
df.drop(df.index[19898:19902],inplace=True) #19898~19901
df.drop(df.index[16941],inplace= True)
df.drop(df.index[16927:16931],inplace=True) #16927~16930
df.drop(df.index[16894:16898],inplace=True) #16894~16897
df.drop(df.index[16581:16585],inplace=True) #16581~16584
df.drop(df.index[16305],inplace= True)
df.drop(df.index[16128:16130],inplace=True) #16128~16129
df.drop(df.index[13519],inplace= True)
df.drop(df.index[9580:9582],inplace=True) #9580~9581
df.drop(df.index[9087:9090],inplace=True) #9087~9089 
df.drop(df.index[7915:7917],inplace=True) # 7915~7916
df.drop(df.index[7497:7500],inplace=True) # 7497~7499
df.drop(df.index[6644],inplace= True)
df.drop(df.index[1526],inplace= True)
df.drop(df.index[1207:1210],inplace=True) #1207~1209
df.drop(df.index[1179:1186],inplace=True) # 1179, 1180, 1181, 1182, 1183, 1184, 1185 삭제

# %%
df.loc[21200:21210]
# Out:
#         section    company       date work_type        job  \
# 21200  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21201  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21202  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21203  엔지니어링·설계   한솔홀딩스(주)  2019년 상반기        신입     화학엔지니어
# 21207  엔지니어링·설계      전력거래소  2019년 상반기        신입  전기·전자엔지니어
# 21208  엔지니어링·설계      전력거래소  2019년 상반기        신입  전기·전자엔지니어
# 21209  엔지니어링·설계      전력거래소  2019년 상반기        신입  전기·전자엔지니어
# 21210  엔지니어링·설계  ㈜포스코인터내셔널  2019년 상반기        신입     화학엔지니어
#
#                                                 question  \
# 21200     지금까지 살아오면서 스스로 생각하기에 가장 큰 성공사례와 실패사례를 소개해 주세요.
# 21201    팀 단위의 과제 혹은 프로젝트 활동 경험을 한 가지 선택하여 자세하게 소개해 주세요.
# 21202                         창의성을 발휘한 경험을 자세하게 소개해 주세요.
# 21203   우리 회사를 지원한 동기와 희망직무에 대하여 준비해 온 것을 기술하여 주시기 바랍니다.
# 21207  개인적인 손해를 감수하면서 맡은 일에 대해 최선을 다했던 경험에 대해 서술해주십시오...
# 21208  공동의 목표를 달성하기 위해 의견/관점 등이 서로 다른 다양한 구성원과 협력하여 시...
# 21209  지금까지 살아오면서 도전해 본 가장 어려운 일에 대해 서술해주십시오. (해당 경험의...
# 21210                   본인을 대표할 수 있는 이력 세가지를 기술하여 주십시오.
#
#                                                   answer
# 21200  1.성공사례 복학 후 2학년 때 '실맥문학회' 동아리의 회장을 맡아 졸업하신 동아리...
# 21201  작년 9월 교내 캡스톤 디자인 공모전을 나간 경험이 있습니다. 공모전 준비를 위해 ...
# 21202  사업계획서를 제작해 지원금을 얻어냈습니다.  대학교 3학년, 학생회 기획부로 있었을...
# 21203  우리나라의 제지산업의 선두주자이며 해외의 기업들까지 인수하며 성장하는 한솔제지에서 ...
# 21207  "밤을 새우며 주어진 업무를 수행했던 경험" 책임감을 느끼고 맡은 업무를 수행하여 ...
# 21208  "직원 모두의 요구를 충족시킨 워크숍 계획. 결과는 대성공!" 단기 현장실습을 하면...
# 21209  "첫 사회생활을 공사현장에서 시작하다!" 4학년 마지막 학기에 건설현장에서 전기현장...
# 21210  "자원개발을 위한 준비들" 화학지식, 꼼꼼함, 외국어 회화 능력을 갖추고 있습니다....

# %%
df.loc[16890:16900]
# Out:
#       section  company       date work_type   job  \
# 16890      영업     유베이스  2016년 하반기        신입  해외영업
# 16891      영업     유베이스  2016년 하반기        신입  해외영업
# 16892      영업     유베이스  2016년 하반기        신입  해외영업
# 16893      영업     유베이스  2016년 하반기        신입  해외영업
# 16898      영업  (주)사조대림  2015년 상반기        신입  영업지원
# 16899      영업  (주)사조대림  2015년 상반기        신입  영업지원
# 16900      영업  (주)사조대림  2015년 상반기        신입  영업지원
#
#                                     question  \
# 16890                                 지원 동기
# 16891                                     강점
# 16892                                     열정
# 16893                                입사 후 포부
# 16898                                   성장과정
# 16899  지원하신 직무를 잘 수행할 수 있다고 생각하는 본인만의 장점(강점)
# 16900                              지원동기 및 포부
#
#                                                   answer
# 16890  [옷을 품고, 세계로] 그 동안 의복에 가져왔던 관심과 애정을 활용할 수 있는 일을...
# 16891  [스케줄 관리 : 한 템포 먼저] 과제나 업무에 대해 우선순위를 설정하고, 시간에 ...
# 16892  [힘들었던 oooo 매장 근무, 배움을 얻었습니다] 2014년 겨울, oooo 일산...
# 16893  [유베이스 인터내셔널과의 동반성장을 추구하겠습니다] 저는 아무리 힘들어도 포기하지 ...
# 16898  [적극적인 삶의 자세와 도전 정신]  ‘1학년 과대표 000’로서 저의 대학생활이 ...
# 16899  [꼼꼼함과 메모습관]  어머니께서는 항상 기록의 중요성을 강조하셨습니다. 보고 듣고...
# 16900  [주인의식과 열정]  자영업을 하고 계신 어머니의 식당을 같이 운영하며 영업관리의 ...
